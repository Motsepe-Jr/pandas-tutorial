# %% [markdown]
# ## Loading data into Pandas

# %%
import pandas as pd

poke = pd.read_csv('pokemon_data.csv')

# poke.head(10)
# poke.tail(10)
poke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
# loading xlxs and txt
# poke_xlxs = pd.read_excel(pokemon_data.xlsx)
# df = pd.read_csv('pokemon_data.txt', delimiter='\t')

# %% [markdown]
# ## Reading Data in Pandas

# %%
# read headers(column)
poke.columns

# read each column
poke['Name'] # retrieve single column, poke.Name
poke[['Name', 'Type 1', 'HP']] # retrieve multple columns

# read each row # indexlocation #read specifc location
# poke.iloc[2,1]

# for index, row in poke.iterrows():
#     print(index, row['Name'])
    
#poke.loc is based on textual infomation

poke.loc[poke['Type 1'] == 'Fire']
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %% [markdown]
# ## Sorting and Describing Data

# %%
poke.describe()
list(poke.columns)
# Out:
# ['#',
#  'Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
# poke.sort_values(['Name', 'HP'], ascending = False)
# poke.sort_values(['Name', 'HP'], ascending = [1, 0])

# %% [markdown]
# ### MAKING CHANGES TO THE DATA

# %%
# poke['Total'] = poke['HP'] + poke['Attack'] + poke['Defense'] + poke['Sp. Atk'] + poke['Sp. Def'] + poke['Speed']
# poke.head(5)
# poke = poke.drop(columns = ['Total']) 

poke['Total'] = poke.iloc[:, 4:10].sum(axis= 1)
cols = list(poke.columns.values)
poke = poke[cols[0:4] + [cols[-1]] + cols[4:12]]
poke
# Out:
#        #                   Name   Type 1  Type 2  Speed  Generation  \
# 0      1              Bulbasaur    Grass  Poison     45           1
# 1      2                Ivysaur    Grass  Poison     60           1
# 2      3               Venusaur    Grass  Poison     80           1
# 3      3  VenusaurMega Venusaur    Grass  Poison     80           1
# 4      4             Charmander     Fire     NaN     65           1
# ..   ...                    ...      ...     ...    ...         ...
# 795  719                Diancie     Rock   Fairy     50           6
# 796  719    DiancieMega Diancie     Rock   Fairy    110           6
# 797  720    HoopaHoopa Confined  Psychic   Ghost     70           6
# 798  720     HoopaHoopa Unbound  Psychic    Dark     80           6
# 799  721              Volcanion     Fire   Water     70           6
#
#      Legendary   Total  HP  Attack  Defense  Sp. Atk  Sp. Def
# 0        False   943.0  45      49       49       65       65
# ...

# %%
# saving our data

# poke.to_csv('modified_poke.csv', index = False)
# poke.to_excel('modified_csv')
# poke.to_csv('modified.csv', sep='\t'), # when saving use sep not delimiter

# %% [markdown]
# ### filtering data

# %%
new_poke = poke.loc[(poke['Type 1'] == 'Grass') & (poke['Type 2'] == 'Poison') & (poke['HP'] > 70)]
# new_poke.reset_index(drop = True, inplace = True)
# new_poke.reset_index()
# Take a look at Mega
import re

# poke.loc[~poke['Name'].str.contains('Mega')]

# use regex

# poke.loc[poke['Type 1'].str.contains('Fire|Grass', regex=True)] # flags=re.I, (Without caps)

# Get name that start with pi

poke.loc[poke['Name'].str.contains('pi[a-z]*', flags=re.I, regex = True)]
# Out:
#        #                     Name    Type 1    Type 2  Speed  Generation  \
# 13    10                 Caterpie       Bug       NaN     45           1
# 20    16                   Pidgey    Normal    Flying     56           1
# 21    17                Pidgeotto    Normal    Flying     71           1
# 22    18                  Pidgeot    Normal    Flying    101           1
# 23    18      PidgeotMega Pidgeot    Normal    Flying    121           1
# 30    25                  Pikachu  Electric       NaN     90           1
# 42    37                   Vulpix      Fire       NaN     65           1
# 76    70               Weepinbell     Grass    Poison     55           1
# 84    78                 Rapidash      Fire       NaN    105           1
# 136  127                   Pinsir       Bug       NaN     85           1
# 137  127        PinsirMega Pinsir       Bug    Flying    105           1
# 181  167                 Spinarak       Bug    Poison     30           2
# ...

# %%
# Condition Changes

# poke.loc[poke['Type 1'] == 'Flammer', 'Type 1'] = 'Fire'
#poke.loc[poke['Total'] > 500, ['Generation', 'Legendary']] = ['Test1', 'test2']
poke = pd.read_csv('pokemon_data.csv')

# %%
# Aggreagte Statitics (Groupby)

#poke.groupby(['Type 1']).mean().sort_values('Defense', ascending = False)

poke['count'] = 1
poke
poke.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64

# %%
# Working with large amounts of data
